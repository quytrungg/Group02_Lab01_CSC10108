# %%
import pandas as pd

# %%
coronaData = pd.read_csv('../data_crawling/March_06_2023_corona_data.csv',thousands=',')
coronaData = coronaData.iloc[: , :11]
coronaData.head(10)
# Out:
#     Country  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0       USA    105396817        NaN     1146740.0         NaN
# 1     India     44688101        NaN      530775.0         NaN
# 2    France     39638159        NaN      165030.0         NaN
# 3   Germany     38210850        NaN      168397.0         NaN
# 4    Brazil     37076053        NaN      699276.0         NaN
# 5     Japan     33264491     4263.0       72805.0        34.0
# 6  S. Korea     30569215     4300.0       34034.0         9.0
# 7     Italy     25603510        NaN      188322.0         NaN
# 8        UK     24370154        NaN      206952.0         NaN
# 9    Russia     22353291    11163.0      396336.0        38.0
#
#    Total Recovered  New Recovered  Active Cases  Serious, Critical  \
# 0      102864696.0            NaN     1385381.0             2726.0
# 1       44154425.0            NaN        2901.0                NaN
# 2       39400459.0          706.0       72670.0              869.0
# ...

# %%
coronaData.info()
coronaData.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            231 non-null    object
#  1   Total Cases        231 non-null    int64
#  2   New Cases          26 non-null     float64
#  3   Total Deaths       225 non-null    float64
#  4   New Deaths         15 non-null     float64
#  5   Total Recovered    210 non-null    float64
#  6   New Recovered      33 non-null     float64
#  7   Active Cases       212 non-null    float64
#  8   Serious, Critical  127 non-null    float64
#  9   Tot Cases/1M pop   229 non-null    float64
#  10  Deaths/1M pop      223 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 20.0+ KB
# Country               object
# Total Cases            int64
# New Cases            float64
# Total Deaths         float64
# New Deaths           float64
# ...

# %%
coronaData.fillna(0)
# Out:
#             Country  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0               USA    105396817        0.0     1146740.0         0.0
# 1             India     44688101        0.0      530775.0         0.0
# 2            France     39638159        0.0      165030.0         0.0
# 3           Germany     38210850        0.0      168397.0         0.0
# 4            Brazil     37076053        0.0      699276.0         0.0
# ..              ...          ...        ...           ...         ...
# 226    Vatican City           29        0.0           0.0         0.0
# 227  Western Sahara           10        0.0           1.0         0.0
# 228      MS Zaandam            9        0.0           2.0         0.0
# 229         Tokelau            5        0.0           0.0         0.0
# 230           China       503302        0.0        5272.0         0.0
#
#      Total Recovered  New Recovered  Active Cases  Serious, Critical  \
# ...

# %%
coronaData.to_csv('./CoronaDataPreprocessing.csv', index=False)
