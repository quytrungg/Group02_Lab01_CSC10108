# %% [markdown]
# ## Import dữ liệu cần thiết

# %%
import pandas as pd

# %% [markdown]
# ## Bước 1: Đọc file CSV

# %%
covid_df = pd.read_csv('../data/original/March_13_2023_corona_data.csv')
covid_df
# Out:
#             Country  Total Cases New Cases Total Deaths  New Deaths  \
# 0               USA  105,602,997       NaN    1,148,785         NaN
# 1             India   44,690,936       NaN      530,782         NaN
# 2            France   39,655,930       NaN      165,163         NaN
# 3           Germany   38,256,003       NaN      169,057         NaN
# 4            Brazil   37,085,520       NaN      699,310         NaN
# ..              ...          ...       ...          ...         ...
# 226    Vatican City           29       NaN          NaN         NaN
# 227  Western Sahara           10       NaN            1         NaN
# 228      MS Zaandam            9       NaN            2         NaN
# 229         Tokelau            5       NaN          NaN         NaN
# 230           China      503,302       NaN        5,272         NaN
#
#     Total Recovered New Recovered Active Cases Serious, Critical  \
# 0       103,160,419           NaN    1,293,793             2,365
# 1        44,156,345           NaN        3,809               NaN
# 2        39,425,027           NaN       65,740               869
# 3        37,868,100       +21,400      218,846               NaN
# 4        36,249,161           NaN      137,049               NaN
# ..              ...           ...          ...               ...
# 226              29           NaN            0               NaN
# 227               9           NaN            0               NaN
# 228               7           NaN            0               NaN
# 229             NaN           NaN            5               NaN
# 230         379,053           NaN      118,977               NaN
#
#     Tot Cases/1M pop  ...    Total tests Tests/1M pop     Population  \
# 0            315,416  ...  1,168,689,987    3,490,656    334,805,269
# 1             31,772  ...    919,671,930      653,811  1,406,631,776
# 2            604,654  ...    271,490,188    4,139,547     65,584,518
# 3            456,061  ...    122,332,384    1,458,359     83,883,596
# 4            172,208  ...     63,776,166      296,146    215,353,593
# ..               ...  ...            ...          ...            ...
# 226           36,295  ...            NaN          NaN            799
# 227               16  ...            NaN          NaN        626,161
# 228              NaN  ...            NaN          NaN            NaN
# 229            3,628  ...            NaN          NaN          1,378
# 230              347  ...    160,000,000      110,461  1,448,471,400
#
#              Continent 1 Case every X ppl 1 Death every X ppl  \
# 0        North America                  3                 291
# 1                 Asia                 31               2,650
# 2               Europe                  2                 397
# 3               Europe                  2                 496
# 4        South America                  6                 308
# ..                 ...                ...                 ...
# 226             Europe                 28                 NaN
# 227             Africa             62,616             626,161
# 228                NaN                NaN                 NaN
# 229  Australia/Oceania                276                 NaN
# 230               Asia              2,878             274,748
#
#     1 Test every X ppl  New Cases/1M pop  New Deaths/1M pop  \
# 0                  0.0               NaN                NaN
# 1                  2.0               NaN                NaN
# 2                  0.0               NaN                NaN
# 3                  1.0               NaN                NaN
# 4                  3.0               NaN                NaN
# ..                 ...               ...                ...
# 226                NaN               NaN                NaN
# 227                NaN               NaN                NaN
# 228                NaN               NaN                NaN
# 229                NaN               NaN                NaN
# 230                9.0               NaN                NaN
#
#      Active Cases/1M pop
# 0                  3,864
# 1                      3
# 2                  1,002
# 3                  2,609
# 4                    636
# ..                   ...
# 226                  NaN
# 227                  NaN
# 228                  NaN
# 229                3,628
# 230                   82
#
# [231 rows x 21 columns]

# %% [markdown]
# ## Bước 2: Xem và chuyển đổi kiểu dữ liệu

# %%
covid_df.dtypes
# Out:
# Country                 object
# Total Cases             object
# New Cases               object
# Total Deaths            object
# New Deaths             float64
# Total Recovered         object
# New Recovered           object
# Active Cases            object
# Serious, Critical       object
# Tot Cases/1M pop        object
# Deaths/1M pop           object
# Total tests             object
# Tests/1M pop            object
# Population              object
# Continent               object
# 1 Case every X ppl      object
# 1 Death every X ppl     object
# 1 Test every X ppl     float64
# New Cases/1M pop       float64
# New Deaths/1M pop      float64
# Active Cases/1M pop     object
# dtype: object

# %%
covid_df['Continent'] = covid_df['Continent'].fillna('Unknown')

covid_df.head(10)
# Out:
#     Country  Total Cases New Cases Total Deaths  New Deaths Total Recovered  \
# 0       USA  105,602,997       NaN    1,148,785         NaN     103,160,419
# 1     India   44,690,936       NaN      530,782         NaN      44,156,345
# 2    France   39,655,930       NaN      165,163         NaN      39,425,027
# 3   Germany   38,256,003       NaN      169,057         NaN      37,868,100
# 4    Brazil   37,085,520       NaN      699,310         NaN      36,249,161
# 5     Japan   33,326,890    +3,368       73,226        27.0      21,703,521
# 6  S. Korea   30,638,929    +4,198       34,115        12.0      30,435,599
# 7     Italy   25,627,473       NaN      188,538         NaN      25,294,864
# 8        UK   24,396,534       NaN      207,695         NaN      24,129,971
# 9    Russia   22,433,361   +10,268      396,620        34.0      21,779,606
#
#   New Recovered Active Cases Serious, Critical Tot Cases/1M pop  ...  \
# 0           NaN    1,293,793             2,365          315,416  ...
# 1           NaN        3,809               NaN           31,772  ...
# 2           NaN       65,740               869          604,654  ...
# 3       +21,400      218,846               NaN          456,061  ...
# 4           NaN      137,049               NaN          172,208  ...
# 5          +995   11,550,143               111          265,374  ...
# 6           NaN      169,215               142          596,902  ...
# 7           NaN      144,071               104          425,262  ...
# 8        +4,846       58,868               NaN          356,165  ...
# 9        +9,476      257,135               NaN          153,858  ...
#
#      Total tests Tests/1M pop     Population      Continent  \
# 0  1,168,689,987    3,490,656    334,805,269  North America
# 1    919,671,930      653,811  1,406,631,776           Asia
# 2    271,490,188    4,139,547     65,584,518         Europe
# 3    122,332,384    1,458,359     83,883,596         Europe
# 4     63,776,166      296,146    215,353,593  South America
# 5     96,226,546      766,227    125,584,838           Asia
# 6     15,804,065      307,892     51,329,899           Asia
# 7    268,674,307    4,458,380     60,262,770         Europe
# 8    522,526,476    7,628,357     68,497,907         Europe
# 9    273,400,000    1,875,095    145,805,947         Europe
#
#   1 Case every X ppl 1 Death every X ppl 1 Test every X ppl  New Cases/1M pop  \
# 0                  3                 291                0.0               NaN
# 1                 31               2,650                2.0               NaN
# 2                  2                 397                0.0               NaN
# 3                  2                 496                1.0               NaN
# 4                  6                 308                3.0               NaN
# 5                  4               1,715                1.0              27.0
# 6                  2               1,505                3.0              82.0
# 7                  2                 320                0.0               NaN
# 8                  3                 330                0.0               NaN
# 9                  6                 368                1.0              70.0
#
#    New Deaths/1M pop  Active Cases/1M pop
# 0                NaN                3,864
# 1                NaN                    3
# 2                NaN                1,002
# 3                NaN                2,609
# 4                NaN                  636
# 5                0.2               91,971
# 6                0.2                3,297
# 7                NaN                2,391
# 8                NaN                  859
# 9                0.2                1,764
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Bước 3: Xóa hết các dấu "+" có trong dữ liệu của 2 thuộc tính "New Cases" và "New Recovered"

# %%
covid_df['New Cases'] = covid_df['New Cases'].apply(lambda x: x.replace('+', '') if isinstance(x, str) else x)
covid_df['New Recovered'] = covid_df['New Recovered'].apply(lambda x: x.replace('+', '') if isinstance(x, str) else x)

covid_df.head(10)
# Out:
#     Country  Total Cases New Cases Total Deaths  New Deaths Total Recovered  \
# 0       USA  105,602,997       NaN    1,148,785         NaN     103,160,419
# 1     India   44,690,936       NaN      530,782         NaN      44,156,345
# 2    France   39,655,930       NaN      165,163         NaN      39,425,027
# 3   Germany   38,256,003       NaN      169,057         NaN      37,868,100
# 4    Brazil   37,085,520       NaN      699,310         NaN      36,249,161
# 5     Japan   33,326,890     3,368       73,226        27.0      21,703,521
# 6  S. Korea   30,638,929     4,198       34,115        12.0      30,435,599
# 7     Italy   25,627,473       NaN      188,538         NaN      25,294,864
# 8        UK   24,396,534       NaN      207,695         NaN      24,129,971
# 9    Russia   22,433,361    10,268      396,620        34.0      21,779,606
#
#   New Recovered Active Cases Serious, Critical Tot Cases/1M pop  ...  \
# 0           NaN    1,293,793             2,365          315,416  ...
# 1           NaN        3,809               NaN           31,772  ...
# 2           NaN       65,740               869          604,654  ...
# 3        21,400      218,846               NaN          456,061  ...
# 4           NaN      137,049               NaN          172,208  ...
# 5           995   11,550,143               111          265,374  ...
# 6           NaN      169,215               142          596,902  ...
# 7           NaN      144,071               104          425,262  ...
# 8         4,846       58,868               NaN          356,165  ...
# 9         9,476      257,135               NaN          153,858  ...
#
#      Total tests Tests/1M pop     Population      Continent  \
# 0  1,168,689,987    3,490,656    334,805,269  North America
# 1    919,671,930      653,811  1,406,631,776           Asia
# 2    271,490,188    4,139,547     65,584,518         Europe
# 3    122,332,384    1,458,359     83,883,596         Europe
# 4     63,776,166      296,146    215,353,593  South America
# 5     96,226,546      766,227    125,584,838           Asia
# 6     15,804,065      307,892     51,329,899           Asia
# 7    268,674,307    4,458,380     60,262,770         Europe
# 8    522,526,476    7,628,357     68,497,907         Europe
# 9    273,400,000    1,875,095    145,805,947         Europe
#
#   1 Case every X ppl 1 Death every X ppl 1 Test every X ppl  New Cases/1M pop  \
# 0                  3                 291                0.0               NaN
# 1                 31               2,650                2.0               NaN
# 2                  2                 397                0.0               NaN
# 3                  2                 496                1.0               NaN
# 4                  6                 308                3.0               NaN
# 5                  4               1,715                1.0              27.0
# 6                  2               1,505                3.0              82.0
# 7                  2                 320                0.0               NaN
# 8                  3                 330                0.0               NaN
# 9                  6                 368                1.0              70.0
#
#    New Deaths/1M pop  Active Cases/1M pop
# 0                NaN                3,864
# 1                NaN                    3
# 2                NaN                1,002
# 3                NaN                2,609
# 4                NaN                  636
# 5                0.2               91,971
# 6                0.2                3,297
# 7                NaN                2,391
# 8                NaN                  859
# 9                0.2                1,764
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Bước 4: Convert các cột có kiểu dữ liệu số về lại đúng kiểu dữ liệu của nó:
#
# Các cột sau đây đã được đưa về về đúng kiểu dữ liệu rồi nên bỏ qua:
# - 1 Test every X ppl
# - New Cases/1M pop
# - New Deaths/1M pop
# - New Deaths

# %%
numeric_cols = ['Total Cases', 'New Cases', 'Total Deaths', 'Total Recovered',
                'New Recovered', 'Active Cases', 'Serious, Critical', 'Tot Cases/1M pop',
                'Deaths/1M pop', 'Total tests', 'Tests/1M pop', 'Population',
                '1 Case every X ppl', '1 Death every X ppl', 'Active Cases/1M pop']

covid_df[numeric_cols] = covid_df[numeric_cols].apply(lambda x: x.str.replace(',', '')).astype(float)
covid_df = covid_df.fillna(0)

# %% [markdown]
# ## Bước 5: Trả về file CSV.

# %%
covid_df.to_csv('../data/modified/Modified_March_13_2023_corona_data.csv', index=False)
